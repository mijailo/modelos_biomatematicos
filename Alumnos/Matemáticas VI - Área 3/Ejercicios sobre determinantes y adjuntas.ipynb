# %% [markdown]
# # Ejercicios sobre determinantes y adjuntas
# (Matemáticas VI - 23 de noviembre de 2021)

# %%
from numpy.linalg import det, inv

# %% [markdown]
# ## Problema 1
# ![image.png](attachment:577870dd-4edd-4950-806c-b41901fc639a.png)

# %%
A=[
    [-2,3,1],
    [0,5,-1],
    [1,1,0]
]
det(A)
# Out:
# -9.999999999999998

# %%
B=[
    [4,1,-5],
    [-2,3,1],
    [3,-1,4]
]

det(B)
# Out:
# 98.00000000000004

# %%
C=[
    [12,7,0],
    [6,7,0],
    [5,8,3]
]

det(C)
# Out:
# 126.0

# %%
D=[
    [8,3,2],
    [5,1,3],
    [6,4,7]
]

det(D)
# Out:
# -62.99999999999999

# %%
E=[
    [2,5,8,3],
    [3,10,2,1],
    [2,4,7,1],
    [1,15,0,4]
]

det(E)
# Out:
# 282.00000000000006

# %% [markdown]
# ## Problema 2
#
# > **Regla de Sarrus**
# ![Sarrus](https://upload.wikimedia.org/wikipedia/commons/2/2d/Schema_sarrus-regel.png)

# %% [markdown]
# ## Problema 3
#
# ![image.png](attachment:4ac33688-7353-4256-ae2d-12ffc6153ebc.png)

# %%
def adj(X):
    return det(X)*inv(X)

# %%
a=[
    [1,-1,1],
    [0,2,-1],
    [1,0,0]
]

adj(a)
# Out:
# array([[-0., -0., -1.],
#        [-1., -1.,  1.],
#        [-2., -1.,  2.]])

# %%
b=[
    [2,5,8],
    [3,10,1],
    [1,15,4]
]

adj(b).round(3) #Redondear a 3 cifras después del punto
# Out:
# array([[ 25., 100., -75.],
#        [-11.,  -0.,  22.],
#        [ 35., -25.,   5.]])

# %%
c=[
    [5,2,-4],
    [6,-3,7],
    [1,2,4]
]

adj(c).round(3)
# Out:
# array([[-26., -16.,   2.],
#        [-17.,  24., -59.],
#        [ 15.,  -8., -27.]])

# %% [markdown]
# ## Problema 4
#
# ![image.png](attachment:5adff181-bee9-4f5c-81b6-a8133fd9c201.png)
#
# La matriz $H-M$ representa el exceso calórico de hombres con respecto a las mujeres, según el grupo de edad.
