# %% [markdown]
# Vamos a utilizar algunos conceptos básicos de [Markdown](https://www.markdownguide.org/). Por ejemplo, vamos a transcribir los siguientes problemitas con su solución:
#
# ![image.png](attachment:image.png)
#
# * **Inciso a**: $a^{2} \times a^{5}=a^{2+5}=a^{7}$.
# * **Inciso b**: $a^{3} \times a^{8}=a^{3+8}=a^{11}$.
# * **Inciso c**: $a^{2} \times a^{4} \times a^{5}=a^{2+4+5}=a^{11}$
